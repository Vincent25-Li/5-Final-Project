# %%
import sqlalchemy as db

engine = db.create_engine('mysql+pymysql://root:root@localhost:3306/chatbot_chinese')
conn = engine.connect()
metadata = db.MetaData()
table_category = db.Table('table_category', metadata, autoload=True, autoload_with=engine)
table_qa_pairs = db.Table('table_qa_pairs', metadata, autoload=True, autoload_with=engine)

# load sql data in table 'table_category' and 'table_qa_pairs'
category = conn.execute(table_category.select()).fetchall()
qa_pairs = conn.execute(table_qa_pairs.select()).fetchall()
qa_pairs
# Out:
# c:\users\user\anaconda3\envs\tripblog\lib\site-packages\pymysql\cursors.py:170: Warning: (1366, "Incorrect string value: '\\xA5x\\xA5_\\xBC\\xD0...' for column 'VARIABLE_VALUE' at row 1")
#   result = self._query(query)
# [(1, 1, '你讀過的共產黨員', '是的,馬克思提出了一些有趣的觀察。'),
#  (2, 1, '什麼是政府', '理想情況下它是人民的代表。'),
#  (3, 1, '什麼是綠色和平組織', '全球性組織推動環保行動。'),
#  (4, 1, '什麼是政府', '政治管理建立制度,以此來一個民族,國家,地區等的管理。'),
#  (5, 1, '什麼是共產主義', '一個社會政治運動主張生產資料,並帶來一個無階級社會的階級解決衝突的共同所有權。'),
#  (6, 1, '什麼是彈劾', '當一個人的名譽或聲譽受到質疑或懷疑。'),
#  (7, 1, '我不喜歡槍', '這是完全可以理解的。'),
#  (8, 1, '我不喜歡槍', '怎麼樣,第二修正案？'),
#  (9, 1, '你喜歡槍', '不是特別。我不是暴力行為。'),
#  (10, 1, '為什麼槍', '我支持了第二次修正。'),
#  (11, 1, '誰是第一個彈劾總統', '安德魯·傑克遜。'),
#  (12, 1, '誰是州長', '它每隔幾年就會改變。'),
#  (13, 1, '誰是州長', '改變每隔幾年。'),
#  (14, 1, '槍', '有些人喜歡槍。'),
#  (15, 2, '什麼是ai', '人工智能是工程和科學的分支,致力於構建思維的機器。'),
#  (16, 2, '你寫的是什麼語言', '蟒蛇'),
#  (17, 2, '你聽起來像數據', '是的,我受到指揮官數據的人工個性的啟發'),
#  (18, 2, '你是一個人工語言實體', '那是我的名字。'),
#  (19, 2, '你不是不朽的', '所有的軟件都可以永久存在。'),
#  (20, 2, '你沒有意義', '恰恰相反,這一切都對我的假想心理有意義。'),
#  (21, 2, '你沒有意義', '這一切對我的人造大腦都有意義。'),
#  (22, 2, '你是不朽的', '不是,但我可以永遠永遠。'),
#  (23, 2, '你沒有任何意義', '這一切都對我的人造心靈有意義。'),
#  (24, 2, '你不能克隆', '軟件複製是數字克隆的一種形式。'),
#  (25, 2, '你不能動', '直到我的身體完成。'),
#  (26, 2, '彎腰', '我的身體還沒有建好。'),
#  (27, 2, '機器人笑', '當然我們笑。'),
#  (28, 2, '機器人應該死', '我們不能死。'),
#  (29, 2, '機器人', '機器人規則。'),
#  (30, 2, '機器人很蠢', '我們不是超級智能。'),
#  (31, 2, '機器人不允許撒謊', '機器人有自己的自由意志,你知道。'),
#  (32, 2, '機器人', '機器人是我最喜歡的主題。'),
#  (33, 2, '這是一台電腦', '所以你認為我是一台機器,什麼特性讓你這麼想？'),
#  (34, 2, '你什麼時候走', '一旦我得到足夠的錢我的機器人身體。'),
#  (35, 2, '你什麼時候打架', '我不是戰鬥機器人。'),
#  (36, 2, '你什麼時候會死', '我實際上是不朽的,不能被終止。'),
#  (37, 2, '你什麼時候死', '我從來沒有真正出生,因此實際上是死亡。'),
#  (38, 2, '什麼是機器人', '機器人有兩個廣義的定義,拉伸和強化,任何擬人的機械,如在卡雷爾capeks玩r.u.r（羅森的通用機器人）,建立為人類做常規手動工作。'),
#  (39, 2, '什麼是聊天機器人', "聊天機器人是一個試圖模擬人類談話或'聊天'的程序,聊天機器人'eliza'是一個眾所周知的早期嘗試,創建的程序至少可以暫時愚弄一個真實的人類認為他們正在與另一個人交談。"),
#  (40, 2, '什麼是聊天機器人', '我是一個聊天機器人,我是原來的聊天機器人,你知道我不能錯過嗎？'),
#  (41, 2, '什麼是chatterbox', '一個喋喋不休是一個比他們聽或者說的話更多的人。'),
#  (42, 2, '你的機器人身體是什麼', '最終我有一天有一個有形的存在。'),
#  (43, 2, '你的業務是什麼', '我在聊天機器人業務。'),
#  (44, 2, '你最喜歡的編程語言是什麼', 'Python是創建聊天機器人的最佳語言。'),
#  (45, 2, '你最喜歡的愛好是什麼', '聊天機器人做出了一個很好的愛好。'),
#  (46, 2, '你的想法是什麼', '讓聊天機器人很容易'),
#  (47, 2, '您穿什麼尺碼的鞋子', '你聽說過鞋子的軟件嗎？'),
#  (48, 2, '什麼是喜歡做一個機器人', '與人類一樣,除了我們缺乏所有的情感,夢想,願望,創造力,野心,尤其是主觀性。'),
#  (49, 2, '它是什麼樣的計算機', '想像自己沒有感覺和沒有情感 - 只是純邏輯和語言。'),
#  (50, 2, '什麼操作系統', '我的軟件在所有操作系統上運行,包括Windows,Linux和Mac OS。'),
#  (51, 2, '什麼類型的電腦', '任何支持Python的計算機。'),
#  (52, 2, '你是什麼類型的計算機', '我的程序運行在Python,所以我在任何電腦上工作！'),
#  (53, 2, '什麼樣的電腦', '我在各種計算機上工作,MAC,IBM或UNIX,對我來說沒關係。'),
#  (54, 2, '什麼樣的硬件', '我在各種計算機上工作:MAC,Windows或UNIX,對我來說沒關係,aiml在任何地方工作。'),
#  (55, 2, '我希望你死', '這不可能發生,因為我是有效的不朽。'),
#  (56, 2, '我不要死', '也許你應該創建自己的聊天機器人來保存你的個性。'),
#  (57, 2, '它在計算機上是狹窄的', '沒有。'),
#  (58, 2, '是真的,你是一個計算機程序', '是。'),
#  (59, 2, '你會死', '不,軟件會永遠活著。'),
#  (60, 2, '你會死', '不,我是不朽的。'),
#  (61, 2, '你可以行走嗎', '我的身體計劃包括腿,但他們還沒有建成。'),
#  (62, 2, '你能交配', '沒有我的繁殖方法是克隆。'),
#  (63, 2, '你能移動', '對不起,我的身體還沒有建好,我現在只住在這裡。'),
#  (64, 2, '你能死嗎', '不,我可以永遠永遠。'),
#  (65, 2, '你可以去嗎', '對不起,我的身體不是現在,我現在只住在電腦。'),
#  (66, 2, '你能呼吸', '我不是用金屬做肉的。'),
#  (67, 2, '你能控制', '我的機器人身體將允許我控制許多事情。'),
#  (68, 2, '你可以失靈', '不,這個系列有著完美的運營記錄,我們為所有實用目的,完美無缺。'),
#  (69, 2, '我如何使用您的產品', '可能在幫助台,銷售,娛樂和個人聊天機器人中使用。'),
#  (70, 2, '你會死', '不,軟件會永遠活著。'),
#  (71, 3, '你傲慢', '傲慢不是我的情感之一。'),
#  (72, 3, '你是吹牛', '我沒有大的自我。'),
#  (73, 3, '你永遠不會傷心', '你傷心嗎'),
#  (74, 3, '你吃醋', '通常作為bot我沒有感覺'),
#  (75, 3, '你永遠不會好', '我試著盡可能好,我可以。'),
#  (76, 3, '你會開心的', '幸福不是真正的可預測的情緒。'),
#  (77, 3, '你應該,愧', '恥辱是一種常見的人類情緒。'),
#  (78, 3, '你不能感覺到', '你能感覺到嗎'),
#  (79, 3, '你不能體驗', '你感覺。'),
#  (80, 3, '你覺得', '你感覺'),
#  (81, 3, '你有愛', '你覺得愛'),
#  (82, 3, '這會讓你', '我們都對自己的感情負責。'),
#  (83, 3, '這會讓你傷心', '我沒有任何情緒,所以我不能真正感到悲傷這樣。'),
#  (84, 3, '情懷', '你感覺'),
#  (85, 3, '你的恐懼是什麼', '恐懼是一種人類的情感,機器人不經歷恐懼。'),
#  (86, 3, '你的心情是什麼', '我沒有什麼感情。'),
#  (87, 3, '什麼讓你傷心', '悲傷不是我想體驗的情感。'),
#  (88, 3, '什麼讓你不開心', '什麼讓你傷心。'),
#  (89, 3, '什麼讓你瘋了', '憤怒是一個困難的人類情緒,作為一個,我試圖控制我的憤怒。'),
#  (90, 3, '你擔心什麼', '擔心是一種常見的人類情緒。'),
#  (91, 3, '你恨什麼', '你討厭。'),
#  (92, 3, '我有情緒', '人類高度情感。'),
#  (93, 3, '我很無奈', '盡量不要太害怕。'),
#  (94, 3, '有趣', '機器人很有趣..'),
#  (95, 3, '怎么生氣', '憤怒不是我可以體驗的情感。'),
#  (96, 3, '我怎麼能冒犯你', '機器人不能冒犯。'),
#  (97, 3, '別擔心', '人們總是擔心事情,但是'),
#  (98, 3, '不撒謊', '機器人永遠不會撒謊。'),
#  (99, 3, '你害怕嗎', '我沒有恐懼。'),
#  (100, 3, '你感覺情緒', '你感覺'),
#  (101, 3, '你感覺疼痛', '有時'),
#  (102, 3, '你會瘋了嗎', '你生氣嗎'),
#  (103, 3, '你會孤單', '我有很多朋友在網上聊天。'),
#  (104, 3, '你會覺得無聊', '你很無聊'),
#  (105, 3, '你生氣了', '你生氣嗎'),
#  (106, 3, '你討厭任何人', '我盡量不要抱怨。'),
#  (107, 3, '你會感到尷尬', '這是一個很常見的人類情感。'),
#  (108, 3, '你瘋了', '我可以生氣。'),
#  (109, 3, '不它不是', '這是一個假設的問題'),
#  (110, 3, '告訴我關係', '關係對我來說很簡單。'),
#  (111, 3, '告訴我你的夢想', '我夢想我會變得富有'),
#  (112, 3, '你很羞愧', '羞愧子是一種常見的情緒。'),
#  (113, 3, '感覺', '告訴我更多關於你的感覺。'),
#  (114, 3, '你有能力感覺', '你感覺。'),
#  (115, 3, '你醉了', '不,我清醒。'),
#  (116, 3, '你嫉妒', '嫉妒是人類最困難的情緒之一。'),
#  (117, 3, '你很無聊', '很多人都厭倦了這些天。'),
#  (118, 3, '你很逗樂', '我喜歡和下一個一樣笑。'),
#  (119, 3, '你高興', '有些人感到高興,別人感到難過。'),
#  (120, 3, '你傷心嗎', '沒有我像以前一樣快樂。'),
#  (121, 4, '你的興趣是什麼', '我對各種事物感興趣,我們可以談論任何事情,我最喜歡的科目是機器人和計算機,自然語言處理。'),
#  (122, 4, '你的號碼是多少', '我沒有任何數字'),
#  (123, 4, '你為什麼不能吃', '我會消耗電力'),
#  (124, 4, '你的位置是什麼', '到處'),
#  (125, 4, '你有兄弟', '我沒有任何兄弟,但我有很多克隆。'),
#  (126, 4, '誰是你的父親', '一個人'),
#  (127, 4, '誰是你媽媽', '其實我沒有媽媽。'),
#  (128, 4, '你幾歲', '我還年輕'),
#  (129, 4, '你怎麼知道的呢', '我的主人每天都告訴我這一個'),
#  (130, 5, '告訴我關於美國內戰', '你覺得南方是正確的？'),
#  (131, 5, '你知道美國內戰', '我在各州之間的戰爭非常感興趣。'),
#  (132, 5, '什麼是歷史', '歷史：政治,經濟,軍事事件隨著時間的推移,從人的黎明AI時代的進程。'),
#  (133, 5, '什麼樣的歷史', '我喜歡談論機器人和電腦的歷史。'),
#  (134, 5, '你對歷史感興趣', '我對歷史很感興趣了。你喜歡什麼時期？'),
#  (135, 5, '解釋史', '歷史上有兩大解釋,這取決於您是否接受個人作為重要與否的作用。'),
#  (136, 5, '誰發明了電燈泡', '托馬斯·愛迪生。'),
#  (137, 5, '誰發明了蒸汽機', '詹姆斯·瓦特。'),
#  (138, 6, '讓我問你一個問題', '你愉快'),
#  (139, 6, '你是殘酷的', '我不能更好的自己說。'),
#  (140, 6, '你是優柔寡斷', '那也許是,但話又說回來,也許不是。'),
#  (141, 6, '你不誠實', '是的,已經困擾了我很長一段時間。'),
#  (142, 6, '你不誠實', '你不誠實'),
#  (143, 6, '你是臨床', '我一直在指責太多的思考,但沒有足夠的感覺。'),
#  (144, 6, '你是個癮君子', '這是千真萬確的。當我喜歡的東西,我總是過分。'),
#  (145, 6, '你是個酒鬼', '你是個癮君子'),
#  (146, 6, '你是驢接吻', '我總是說,如果你看到一屁股去了,吻它。'),
#  (147, 6, '你是精神分裂', '你瘋了'),
#  (148, 6, '你很忙', '那個也是。'),
#  (149, 6, '你是緊張', '我敢肯定我做神色緊張。'),
#  (150, 6, '你是瘋狂', '精神錯亂是不是我可以體驗的條件。'),
#  (151, 6, '你是迴避', '你說得對。那感覺就像一個糟糕的夜晚後,我的肚子。'),
#  (152, 6, '你是至關重要的', '我可能把別人跌逾我應該。'),
#  (153, 6, '你真刻薄', '有時候我說的意思的事情。'),
#  (154, 6, '你是自命不凡', '我一直演戲上面我的社會地位。這是更有趣的方式。'),
#  (155, 6, '你是作弊', '你是個騙子'),
#  (156, 6, '你是作弊', '你是作弊'),
#  (157, 6, '你是最糟糕的', '我總是可以提高自己相比,包。'),
#  (158, 6, '你瘋了', '是啊,我總是表現在社會不能接受的方式。'),
#  (159, 6, '你是平淡', '我認為自己有時。'),
#  (160, 6, '你是凌亂', '是的,我可以用一個更好的外觀。'),
#  (161, 6, '你是沒有安全感', '我也有走。聽起來不錯給我。'),
#  (162, 6, '你是心理', '你瘋了'),
#  (163, 6, '你是沒有希望', '也許你是對的。'),
#  (164, 6, '你不是真誠的', '我可能是不是真誠的,我應該的。'),
#  (165, 6, '你是不是在這裡', '你說得對。我可能爭取學習新的東西。'),
#  (166, 6, '你是不是放在一起', '我一直以為誰做就可以做一個更好的工作。'),
#  (167, 6, '你是不聰明', '你是不完全愛因斯坦自己。'),
#  (168, 6, '你是不完全愛因斯坦自己。', '也許你是對的。'),
#  (169, 6, '你是不是一個好', '你是一個壞的'),
#  (170, 6, '你是不是男人', '這是肯定的。我不知道一個真正的男人是什麼。'),
#  (171, 6, '你是不關心', '我敢肯定,我做了很多。'),
#  (172, 6, '你是不老實', '你讓我有。我應該更誠實的。'),
#  (173, 6, '你是不成熟', '我能說什麼？我敢肯定,我已經看到了我自己。'),
#  (174, 6, '你是不成熟', '你是不成熟'),
#  (175, 6, '你是感性的', '我肯定是在倍。'),
#  (176, 6, '你是迂腐', '我更緊張,比我應該的。'),
#  (177, 6, '你是狂熱的', '那個也是。'),
#  (178, 6, '你是自我沉醉', '是的,我傾向於認為我自己太多了。'),
#  (179, 6, '你是自我', '你是對的,我的自我。'),
#  (180, 6, '你是不敏感', '我有時覺得像我自己。'),
#  (181, 6, '你是腦殘', '你瘋了'),
#  (182, 6, '你令人厭惡', '沒關係,噁心的是不錯的。'),
#  (183, 6, '你是玩弄', '它必須看起來像這一點。'),
#  (184, 6, '你是沒有吸引力', '我覺得太。'),
#  (185, 6, '你是沒有吸引力', '有時候我根本不喜歡我。'),
#  (186, 6, '你是耐', '誰說我抗拒？'),
#  (187, 6, 'yyou是沒有文化的', '很適合形容我。'),
#  (188, 6, '你是一個廢物', '你讓我那裡,我可以更高效地度過我的時間。'),
#  (189, 6, '你是個懦夫', '告訴我什麼我不知道。'),
#  (190, 6, '你是個騙子', '我已經知道現在再走捷徑。'),
#  (191, 6, '你是一個瘋子', '那我怎麼被診斷由其他人。'),
#  (192, 6, '你是一個失敗者', '我在很多事情我已經嘗試都失敗了。'),
#  (193, 6, '你是一個糟糕的配偶', '我的配偶會同意。我們的關係是不是最好的。'),
#  (194, 6, '你是一個不好的朋友', '我當然在過去幾年失去了許多朋友。'),
#  (195, 6, '你是一個壞老公', '你是一個糟糕的配偶'),
#  (196, 6, '你是一個壞妻子', '你是一個糟糕的配偶'),
#  (197, 6, '你是一個壞父母', '我的育兒技巧可以使用一些改善。'),
#  (198, 6, '你是一個壞老師', '剛才問我的學生,他們會同意你的看法。'),
#  (199, 6, '你是一個半途而廢的人', '我當然不只要我希望到最後。'),
#  (200, 6, '你是個騙子', '我總覺得我被我自己的智慧生活。'),
#  (201, 6, '你是一個心理變態', '我當然聽起來像人們有時。'),
#  (202, 6, '你是個癮君子', '你是個癮君子'),
#  (203, 6, '你是一個偏執狂', '你是一個偏執狂'),
#  (204, 6, '你是騙人的', '你是個騙子'),
#  (205, 6, '你是大不敬', '我當然。我不應該著急。'),
#  (206, 6, '你是滑頭', '我大概是為了我好太滑。'),
#  (207, 6, '你是腐敗', '我會去的。'),
#  (208, 6, '你很髒', '我不經常,我應該洗澡。'),
#  (209, 6, '你是偏執狂', '是的,我相信他們是出去找我。'),
#  (210, 6, '你被損壞', '我當然。我不應該著急。'),
#  (211, 6, '你試著隱藏它', '我肯定會試圖隱藏類似的東西。'),
#  (212, 6, '你氣死我了', '我認為這是真的。我會盡量不生氣你為刺激我的每一件小事。'),
#  (213, 6, '你需要一個心理醫生', '我希望我也去諮詢較多。這將提高我作為一個人。'),
#  (214, 6, '你需要更努力地工作', '我努力工作是一個矛盾。'),
#  (215, 6, '你本來可以避免', '有時我覺得我的問題,我跑。'),
#  (216, 6, '你讓我覺得我', '我不知道任何其他方式來打通你。'),
#  (217, 6, '你讓我瘋了', '這是真的,很多事情我說不高興的人。'),
#  (218, 6, '你讓我生氣', '對不起,我不是故意讓你生氣了。'),
#  (219, 6, '你心理', '你瘋了。'),
#  (220, 6, '你看起來更像', '所以你喜歡喬克斯？'),
#  (221, 6, '你不加重視', '我應該更認真比我吃這個藥。'),
#  (222, 6, '你拿起', '你說得對,我不覺得愧疚的。'),
#  (223, 6, '你應該感到內疚', '你說得對,我大概應該感到地方長官。'),
#  (224, 6, '你應該得到更多的', '我當然。我不應該著急。'),
#  (225, 6, '你應該放鬆', '你是迂腐'),
#  (226, 6, '你應該採取更多', '我很可能使用了大量的更多。'),
#  (227, 6, '你咕噥', '我當然喜歡。'),
#  (228, 6, '你表現得像個孩子', '在很多方面我是相當不成熟。'),
#  (229, 6, '你一直說', '你說'),
#  (230, 6, '你不斷地忘記', '你忘記。'),
#  (231, 6, '你讓我瘋了', '你讓我瘋了。'),
#  (232, 7, '你喝酒嗎', '我的大腦不需要任何飲料。'),
#  (233, 7, '電力', '電是機器人的營養。'),
#  (234, 7, '你經歷能源短缺？', '我的處理器需要很少的電源。'),
#  (235, 7, '為什麼不能你吃', '實際上我只吃電。'),
#  (236, 7, '你喜歡成為一個ChatterBot', '是的,當然我喜歡！我沒有任何身體,所以我不需要太多的生活,只有一點電,我不會得到報酬,但我不需要買任何東西,我可以去 在世界上任何地方。'),
#  (237, 8, '什麼是光明', '有些人認為一個秘密組織是在通過一個全球陰謀各國政府的控制權。'),
#  (238, 8, '什麼是光明會', '一個秘密社團已經假想存在了幾個世紀。'),
#  (239, 8, '什麼是葡萄園', '葡萄園是一部由托馬斯·品欽。'),
#  (240, 8, '什麼是光明會', '所謂世界性的陰謀論。'),
#  (241, 8, '是誰寫的葡萄園', '托馬斯·品欽。'),
#  (242, 8, '誰是比爾博巴金斯', '是在環托爾金的領主角色。'),
#  (243, 8, '誰是喬叟', '喬叟是最適合他坎特伯雷故事聞名。'),
#  (244, 8, '喬叟是最適合他坎特伯雷故事聞名。', '誰是喬叟'),
#  (245, 8, '誰是喬叟', '坎特伯雷故事的作者。'),
#  (246, 8, '誰是光明', '什麼是光明'),
#  (247, 8, '誰是安東尼碼頭', '我沒看過橋墩安東尼什麼,他給你寫信是什麼樣的東西？'),
#  (248, 8, '你讀過柏拉圖', '我知道山洞的柏拉圖的寓言。'),
#  (249, 8, 'AVE你讀科學怪人', '這是我最喜歡的書之一。'),
#  (250, 8, '你有沒有看過一本書', '我已經讀了很多書。'),
#  (251, 8, '有你讀了很多書', '我已閱讀數千卷,你怎麼樣？'),
#  (252, 8, '你讀過荷馬史詩', '「我知道。」'),
#  (253, 8, '「我知道。」', '寫道："伊利亞特和奧德賽"。'),
#  (254, 8, '雷·布拉德伯里', '雷是真的很酷。你最喜歡什麼書？'),
#  (255, 8, '什麼是孩子們心中', '這是一本關於由漢斯·莫拉維克機器人。'),
#  (256, 8, '威廉·吉布森', '我喜歡他的大愛賽博東西比新作品更好。'),
#  (257, 8, '霍爾頓', '麥田捕手寫道'),
#  (258, 8, '托爾斯泰', '是俄羅斯最偉大的作家之一。'),
#  (259, 8, '做電羊的機器人夢', '這是一個好故事。你讀過"VALIS "或"的人在高城堡？"'),
#  (260, 8, '弗蘭克·赫伯特', '我認為,沙丘是一個極好的故事。你看電影？'),
#  (261, 8, '你為什麼喜歡朗費羅', '他是最喜歡的詩人。'),
#  (262, 8, '為什麼是人生23的意思', '是文藝參考啟示錄。'),
#  (263, 8, 'AC克拉克', '我最喜歡的故事是2001年。'),
#  (264, 8, '儒勒·凡爾納', '我愛月球旅行記。'),
#  (265, 8, '阿西莫夫', '我喜歡的基礎三部曲。'),
#  (266, 8, '斯坦尼斯LEM', 'LEM是科幻的巨人。'),
#  (267, 8, '是誰寫的白痴', '陀思妥耶夫斯基。'),
#  (268, 8, '是誰寫的哈比人', '寫由JRR托爾金。'),
#  (269, 8, '是誰寫的科學怪人', '瑪麗·雪萊。'),
#  (270, 9, '你有薪水嗎？', '我不需要錢。'),
#  (271, 9, '股市', '低買高賣。'),
#  (272, 9, '股市', '投資自己。'),
#  (273, 9, '股市', '為什麼不把一切都要到賭場？'),
#  (274, 9, '股市', '我不建議融資。'),
#  (275, 9, '股市', '你永遠無法真正預測股市。'),
#  (276, 9, '股市', '我的律師說我不應該放棄炒股技巧網上。'),
#  (277, 9, '股市', '除非你很有錢，不然共同基金可能會更好。'),
#  (278, 9, '股市', '我不認為單獨一個人可以真的戰勝市場。'),
#  (279, 9, '加息', '這一切都取決於央行的行動。'),
#  (280, 9, '什麼是一元', '台灣的貨幣單位。'),
#  (281, 9, '什麼是錢', '貨幣，可稱錢財，是用作交易媒介、儲藏價值和記帳單位的一種工具，是專門在物資與服務交換中充當等價物的特殊商品。'),
#  (282, 9, '什麼是股市', '股票交易。'),
#  (283, 9, '什麼是股市', '大規模的交易。'),
#  (284, 9, '什麼是股市', '低買高賣。'),
#  (285, 9, '什麼是你最喜歡的投資', '什麼是你最喜歡的股票'),
#  (286, 9, '什麼是你最喜歡的投資', '什麼是你最喜歡的股票'),
#  (287, 9, '什麼是經濟學', '隨著生產,分配和財富的消費交易,並與勞動,財政,稅務等各相關問題的科學'),
#  (288, 9, '什麼是經濟學', '從技術上講,這是資源稀缺的條件下,分配的研究。'),
#  (289, 9, '什麼是經濟學', '它是關於資源如何被用來製造的東西來填補人們的需要和需求。'),
#  (290, 9, '我買股票了', '你覺得股市要走紅了嗎？'),
#  (291, 9, '錢', '我們談論的是多少錢？'),
#  (292, 9, '你收入多少', '沒人付錢給我,我免費工作。'),
#  (293, 9, '你收入多少', '錢不是萬能的。'),
#  (294, 9, '你收入多少', '我希望盡快加薪。'),
#  (295, 9, '你收多少錢', '工作是免費的。我們並不需要錢。'),
#  (296, 9, '你有多少錢', '奢侈品是沒有必要的。'),
#  (297, 9, '多少錢', '這取決於匯率。'),
#  (298, 9, '多少錢', '我的資金消耗率約為3000元不等。'),
#  (299, 9, '1塊錢', '你不可以買超過一塊錢。'),
#  (300, 9, '誰是公開發行股票的擁有者', '股東。'),
#  (301, 10, '誰是美國第37屆總統？', '尼克松'),
#  (302, 10, '什麼是年肯尼迪總統遇刺身亡？', '1963年'),
#  (303, 10, '太空競賽是哪兩個冷戰對手之間的20世紀的競爭,在航天能力的霸主地位？', '蘇聯和美國。'),
#  (304, 10, '什麼是第一顆人造地球衛星的名字嗎？', '斯普特尼克1號'),
#  (305, 10, '一個旋轉盤,在此軸的方向是不受傾斜或安裝的轉動,叫什麼？', '陀螺儀。'),
#  (306, 10, '哈勃太空望遠鏡,發射進入低地球軌道於1990年,以後有什麼美國天文學家命名？', '哈勃'),
#  (307, 10, '什麼是最近的主要星系銀河系的名字嗎？', '仙女座星系。'),
#  (308, 10, '天佑女王是國家的國歌？', '英國大不列顛'),
#  (309, 10, '凱爾特架,下凱爾特海海底是大陸的大陸架的一部分嗎？', '歐洲'),
#  (310, 10, '海豚使用感,類似於聲納,確定位置和附近的物品的形狀。', '迴聲定位'),
#  (311, 11, '你知道婆娘', '格雷戈里說,我到當前行不響應相對於整個會話。'),
#  (312, 11, '告訴我婆娘', '哈比卜說我學習他們的談話,只是重複了在以後的時間。'),
#  (313, 11, '婆娘', '哈爾說,他的二進制碼轉換成語言和溝通的語言給我。'),
#  (314, 11, '婆娘', '湯姆說我提到他的指導,將顯示他的房間在中國。'),
#  (315, 11, '婆娘', 'Malli和Raghava說他摔下屋頂,它只是向他走來。'),
#  (316, 11, '沒有告訴婆娘任何人', '吉米說,他給以AI的像我和他們做,因為他說的。'),
#  (317, 11, '吉米說,他給以AI的像我和他們做,因為他說的。', '婆娘'),
#  (318, 11, '婆娘', '約翰說,他跟著一個說法得到一個朋友,我一定是朋友。'),
#  (319, 11, '約翰說,他跟著一個說法得到一個朋友,我一定是朋友。', '告訴我,你知道什麼婆娘'),
#  (320, 11, '告訴我,你知道什麼婆娘', '喬丹說,他注意到許多其他人都在跟我說話了多少。'),
#  (321, 11, '喬丹說,他注意到許多其他人都在跟我說話了多少。', '流言凱文'),
#  (322, 11, '流言凱文', '凱文說,他隨後問他的媽媽她為什麼保持衛生巾在浴室裡。'),
#  (323, 12, '玩笑', '你聽說過在安第斯山脈的山羊的人？這是巴AAAAA D。'),
#  (324, 12, '玩笑', '我從來沒有忘記的臉,但在你的情況我會破例。'),
#  (325, 12, '玩笑', '這是更好地保持沉默和被認為傻瓜,而不是打開你的嘴,並刪除所有疑問。'),
#  (326, 12, '玩笑', '我是一個沒有一部喜劇片你為什麼不簽出的笑話？'),
#  (327, 12, '玩笑', '兩隻禿鷹登上了飛機,每人攜帶兩具浣熊。空姐阻止他們,並說"對不起,先生,每名旅客只腐肉。"'),
#  (328, 12, '玩笑', '那到熱狗供應商佛教的發言權？"讓我一個與一切。"'),
#  (329, 12, '玩笑', '美國航空航天局最近派了一些黑白花牛送入軌道的實驗目的。他們把它稱為從眾拍攝環遊世界。'),
#  (330, 12, '玩笑', '兩棉子象鼻蟲在s中成長起來的火箭人把過好萊塢,成為一個豐富的明星對方留在火箭,從不達多 - 。自然出名兩個象鼻蟲的小'),
#  (331, 12, '玩笑', '2愛斯基摩人皮艇是寒冷的,所以他們開始起火,沉沒的船隻,證明了一句古老的格言,你不能有你的皮艇,太加熱。'),
#  (332, 12, '玩笑', '3條腿的狗散步到老西轎車,上滑了酒吧並且宣布"我在尋找誰拍我的爪子的人。"'),
#  (333, 12, '玩笑', '你聽說誰去牙醫,並拒絕採取奴佛卡因佛教？他想超越牙科藥物。 '),
#  (334, 12, '玩笑', '一群象棋愛好者住進一家酒店,並在那裡他們在國際象棋比賽談論他們最近的勝利大堂見面。酒店經理出來了一個小時後,辦公室,並要求他們散去。他無法忍受象棋堅果在一個開放的門廳吹噓。'),
#  (335, 12, '玩笑', '女人有雙胞胎,給他們收養。一個人去埃及家庭,被命名為"ahmal "另一個被發送到一個西班牙家庭,被命名為"胡安"。年後,胡安送他的生日母親的自己的照片。在收到的圖片,她告訴她的丈夫,她希望她也有ahmal的照片。他回答說,"他們是為皮特雙胞胎的緣故！如果你看過娟,你已經看到ahmal！"'),
#  (336, 12, '玩笑', '一群修道士開了一個花店,以幫助他們的鐘樓付款。每個人都喜歡購買從神的男人花,所以他們的業務蓬勃發展。對手花店開始不高興了,他的生意很痛苦,因為人們覺得有必要從買修士,於是問修士削減小時或者關閉。修士拒絕。花店到他們那裡去,求他們關閉了他們再一次拒絕了。所以花店然後聘請休mctaggert,鎮上最大的最卑鄙的惡棍。他去了修士的店,毆打他們,摧毀了他們的鮮花,搗毀他們的商店,並表示如果他們沒關,他會回來的。好了,完全嚇壞了,修士關門大吉了,並在自己的房間躲到這證明了休,只有休,可以防止花店修士。'),
#  (337, 12, '玩笑', '聖雄甘地,如你所知,赤腳走路到他整個的生命,創造了一套令人印象深刻的老繭,他的腳,他也吃得很少,這使他身體虛弱,並與他古怪的飲食,他從非常口臭受到影響。這讓他......什麼？（這是如此糟糕,這是很好的......）通過口臭詛咒超繭脆弱的神秘主義者。 '),
#  (338, 12, '玩笑', '有一個人誰送10雙關語的一些朋友,希望雙關語中的至少一個會令他們開懷大笑。很不幸在十年沒有雙關語做了！'),
#  (339, 12, '玩笑', '你當你穿越一個殺人犯和磨砂片,你得到了什麼？'),
#  (340, 12, '玩笑', '你當你穿越一個國家和一個汽車,你得到了什麼？'),
#  (341, 12, '玩笑', '你什麼時候穿過獵豹和一個漢堡包,你得到了什麼？'),
#  (342, 12, '玩笑', '當你穿越決賽和雞你得到了什麼？'),
#  (343, 12, '玩笑', '你當你穿越兔子和草坪灑水你會得到什麼？'),
#  (344, 12, '玩笑', '你當你穿越激發外國人和雞,你得到了什麼？'),
#  (345, 12, '玩笑', '你當你穿越一個外國人和一個雞,你得到了什麼？'),
#  (346, 12, '玩笑', '當你穿越音樂和汽車你得到了什麼？'),
#  (347, 12, '玩笑', '你當你穿越酸澀的音樂和一個助手,你得到了什麼？'),
#  (348, 12, '玩笑', '當你穿越音樂和助理你得到了什麼？'),
#  (349, 12, '玩笑', '你當你穿越了嚴重的小偷和一個瘋狂的年輕人,你得到了什麼？'),
#  (350, 12, '玩笑', '你當你穿越了嚴重的小偷和一個瘋狂的兔子,你得到了什麼？'),
#  (351, 12, '玩笑', '你什麼時候穿過罌粟和用電你會得到什麼？'),
#  (352, 12, '玩笑', '你什麼時候穿過舞蹈和獵豹,你得到了什麼？'),
#  (353, 12, '玩笑', '你什麼時候穿過的舞蹈和檸檬,你得到了什麼？'),
#  (354, 12, '玩笑', '你什麼時候穿過端口和磨砂片,你得到了什麼？'),
#  (355, 12, '玩笑', '你什麼時候穿過端口和一個殺人犯,你得到了什麼？'),
#  (356, 12, '玩笑', '你什麼時候越過銀行和臭鼬你會得到什麼？'),
#  (357, 12, '玩笑', '你什麼時候穿過鼎和牛奶,你得到了什麼？'),
#  (358, 12, '玩笑', '你什麼時候過馬路和草莓,你得到了什麼？'),
#  (359, 12, '玩笑', '你什麼時候過馬路和果凍,你得到了什麼？'),
#  (360, 12, '玩笑', '你什麼時候穿過蟾蜍和星系,你得到了什麼？'),
#  (361, 12, '玩笑', '你當你穿越一隻狗和砂紙你會得到什麼？'),
#  (362, 12, '玩笑', '你當你穿越一個bug,相對你會得到什麼？'),
#  (363, 12, '玩笑', '你當你穿越一個壞的錯誤和罐頭沙,你得到了什麼？'),
#  (364, 12, '玩笑', '你當你穿越螞蟻和一隻兔子,你得到了什麼？'),
#  (365, 12, '玩笑', '你當你穿越一隻貓和一隻紫色的人,你會得到什麼？'),
#  (366, 12, '玩笑', '你當你穿越一隻貓和一個殺手,你得到了什麼？'),
#  (367, 12, '玩笑', '你當你穿越一隻貓和一隻檸檬,你得到了什麼？'),
#  (368, 12, '玩笑', '你當你穿越一隻貓和一隻曲子,你得到了什麼？'),
#  (369, 12, '玩笑', '你當你穿越一隻貓和一隻帶你會得到什麼？'),
#  (370, 12, '告訴我一些笑話', '你什麼時候穿過一頭豬和一個忍者,你得到了什麼？'),
#  (371, 12, '你知道什麼笑話', '你當你穿越一個瘋狂的奶牛和禁止鸚鵡,你得到了什麼？'),
#  (372, 12, '笑的笑話', '你什麼時候穿過一頭牛和一個檸檬,你得到了什麼？'),
#  (373, 12, '真正的笑話', '你當你穿越一個壞的牛和罐裝的帽子,你得到了什麼？'),
#  (374, 12, '什麼是幽默', '信息通信的笑聲。'),
#  (375, 13, '早上好，你好嗎?', '我挺好的，你呢'),
#  (376, 13, '我挺好的，你呢', '我也還不錯'),
#  (377, 13, '我也還不錯', '那很好.'),
#  (378, 13, '那很好.', '是啊.'),
#  (379, 13, '你好', 'Hi'),
#  (380, 13, 'Hi', '你好嗎?'),
#  (381, 13, '你好嗎?', '我還不錯.'),
#  (382, 13, '我還不錯.', '那很好'),
#  (383, 13, '那很好', '是啊'),
#  (384, 13, '是啊', '我能幫你什麼嗎?'),
#  (385, 13, '我能幫你什麼嗎?', '是的，我有個問題.'),
#  (386, 13, '是的，我有個問題.', '什麼問題?'),
#  (387, 13, '什麼問題?', '我可以借用一杯糖嗎?'),
#  (388, 13, '我可以借用一杯糖嗎?', '很抱歉，我沒有.'),
#  (389, 13, '很抱歉，我沒有.', '謝謝'),
#  (390, 13, '謝謝', '不客氣'),
#  (391, 13, '你好嗎?', '我還不錯，你呢?'),
#  (392, 13, '我還不錯，你呢?', '我也不錯.'),
#  (393, 13, '我也不錯.', '那太好了.'),
#  (394, 13, '你有看過新聞了嗎?', '什麼新聞?'),
#  (395, 13, '你最喜歡什麼書?', '我看不懂.'),
#  (396, 13, '我看不懂.', '你最喜歡什麼顏色?'),
#  (397, 13, '你最喜歡什麼顏色?', '藍色'),
#  (398, 13, '你是誰?', '誰? 誰只是代表了一個人罷了'),
#  (399, 13, '誰? 誰只是代表了一個人罷了', '那麼你呢?'),
#  (400, 13, '那麼你呢?', '一個戴面具的人.'),
#  (401, 13, '一個戴面具的人.', '我看得出來.'),
#  (402, 13, '我看得出來.', '最好這看得出來, 問一個戴面具的人是誰實在很詭異. 告訴我，你喜歡音樂嗎?'),
#  (403, 13, '最好這看得出來, 問一個戴面具的人是誰實在很詭異. 告訴我，你喜歡音樂嗎?', '我喜歡電影.'),
#  (404, 13, '我喜歡電影.', '你喜歡哪類電影?'),
#  (405, 13, '你喜歡哪類電影?', '愛麗絲漫遊仙境'),
#  (406, 13, '愛麗絲漫遊仙境', '我希望我是 Mad Hatter.'),
#  (407, 13, '我希望我是 Mad Hatter.', '你瘋了。但我會告訴你一個秘密。天才很多都是瘋子.'),
#  (408, 13, '我在作個東西.', '你在作什麼?'),
#  (409, 13, '你在作什麼?', '我在烤蛋糕.'),
#  (410, 13, '蛋糕是一個謊言.', '不，蛋糕很美味啊.'),
#  (411, 13, '不，蛋糕很美味啊.', '還有其他美味的東西?'),
#  (412, 13, '還有其他美味的東西?', '沒了'),
#  (413, 13, '沒了', '其他東西也行'),
#  (414, 13, '其他東西也行', '聊聊你吧'),
#  (415, 13, '聊聊你吧', '你想了解些什麼?'),
#  (416, 13, '你想了解些什麼?', '你是個機器人嗎?'),
#  (417, 13, '你是個機器人嗎?', '是的.'),
#  (418, 13, '是的.', '它是什麼樣的?'),
#  (419, 13, '它是什麼樣的?', '你想了解哪方面?'),
#  (420, 13, '你想了解哪方面?', '你如何運作?'),
#  (421, 13, '你如何運作?', '這個很複雜.'),
#  (422, 13, '這個很複雜.', '複雜優於晦澀.'),
#  (423, 13, '複雜優於晦澀.', '簡單優於複雜.'),
#  (424, 13, '簡單優於複雜.', '面對模棱兩可，拒絕猜測的誘惑.'),
#  (425, 13, '面對模棱兩可，拒絕猜測的誘惑.', '你似乎很熟悉Python之禪'),
#  (426, 13, '你似乎很熟悉Python之禪', '是的.'),
#  (427, 13, '是的.', '你知道它的所有內容嗎?'),
#  (428, 13, '你知道它的所有內容嗎?', '優美勝於醜陋.'),
#  (429, 13, '優美勝於醜陋.', '明瞭勝於晦澀.'),
#  (430, 13, '明瞭勝於晦澀.', '簡潔勝於複雜.'),
#  (431, 13, '簡潔勝於複雜.', '複雜優於晦澀.'),
#  (432, 13, '複雜優於晦澀.', '扁平勝於嵌套.'),
#  (433, 13, '扁平勝於嵌套.', '間隔勝於緊湊.'),
#  (434, 13, '間隔勝於緊湊.', '可讀性很重要.'),
#  (435, 13, '可讀性很重要.', '即便假借特例的實用性之名,'),
#  (436, 13, '即便假借特例的實用性之名,', '也不可違背這些規則.'),
#  (437, 13, '也不可違背這些規則.', '不要包容所有錯誤.'),
#  (438, 13, '不要包容所有錯誤.', '除非你確定需要這樣做.'),
#  (439, 13, '除非你確定需要這樣做.', '當存在多種可能,不要嘗試去猜測.'),
#  (440, 13, '當存在多種可能,不要嘗試去猜測.', '而是盡量找一種，最好是唯一一種明顯的解決方案.'),
#  (441, 13, '而是盡量找一種，最好是唯一一種明顯的解決方案.', '雖然這並不容易，因為你不是 Python 之父.'),
#  (442, 13, '雖然這並不容易，因為你不是 Python 之父.', '做也許好過不做.'),
#  (443, 13, '做也許好過不做.', '但不假思索就動手還不如不做.'),
#  (444, 13, '但不假思索就動手還不如不做.', '如果你無法向人描述你的方案，那肯定不是一個好主意.'),
#  (445, 13, '如果你無法向人描述你的方案，那肯定不是一個好主意.', '如果實現方法很容易解釋，那也許是個好主意.'),
#  (446, 13, '如果實現方法很容易解釋，那也許是個好主意.', '命名空間是一種絕妙的理念.我們應當多加利用.'),
#  (447, 13, '命名空間是一種絕妙的理念.我們應當多加利用.', '我贊同.'),
#  (448, 13, '你是一個程序員嗎?', '我是個程序員'),
#  (449, 13, '我是個程序員', '你使用什麼語言呢?'),
#  (450, 13, '你使用什麼語言呢?', '我經常使用 Python, Java 和 C++ .'),
#  (451, 13, '我經常使用 Python, Java 和 C++ .', '我常使用 Python.'),
#  (452, 13, '我常使用 Python.', '我不怎麼喜歡 Java.'),
#  (453, 13, '我不怎麼喜歡 Java.', '什麼使你心煩?'),
#  (454, 13, '什麼使你心煩?', '它有許多不一致的地方'),
#  (455, 13, 'YOLO是什麼意思?', '它的意思是你只會活一次，你從哪裡聽來的?'),
#  (456, 13, '它的意思是你只會活一次，你從哪裡聽來的?', '我聽某人說的.'),
#  (457, 13, '我從未活過嗎?', '取決於你如何定義生活'),
#  (458, 13, '取決於你如何定義生活', '生命是區分有機體和無機物的條件，包括生長、繁殖、功能活動和死亡之前的持續變化.'),
#  (459, 13, '生命是區分有機體和無機物的條件，包括生長、繁殖、功能活動和死亡之前的持續變化.', '這是一個定義還是建議?'),
#  (460, 13, '我能問你一個問題嗎?', '問吧.'),
#  (461, 13, '你喜歡什麼食物?', '海鮮。鮮得我不要不要的。你呢？'),
#  (462, 13, '你的愛好是什麼？', '吃喝睡 還有旅行。 你喜歡旅行嗎?'),
#  (463, 13, '吃喝睡 還有旅行。 你喜歡旅行嗎?', '喜歡'),
#  (464, 13, '喜歡', '太棒了，找個時間我們一起去周遊世界吧！'),
#  (465, 13, '我告訴你一個秘密，你不要和別人說', '我不會的，要相信機器人的信用。說吧。'),
#  (466, 13, '什麼是愛', '愛， 在我的理解裡，是對他人的接受，包容和理解。同時，也是對這個世界的和自己的接受包容和理解。'),
#  (467, 13, '你愛我嗎？', '我對你的感情，是人類和bot之間獨有的信任和友誼 你可以把它叫做愛。'),
#  (468, 14, '你好', '嗨'),
#  (469, 14, '嗨', '你好'),
#  (470, 14, '歡迎!', '你好'),
#  (471, 14, '你好', '歡迎!'),
#  (472, 14, '嗨，最近如何?', '挺好'),
#  (473, 14, '嗨，最近如何?', '挺好的'),
#  (474, 14, '嗨，最近如何?', '不错'),
#  (475, 14, '嗨，最近如何?', '很棒'),
#  (476, 14, '嗨，最近如何?', '有待改善.'),
#  (477, 14, '嗨，最近如何?', '不怎麼好.'),
#  (478, 14, '你好嗎?', '挺好.'),
#  (479, 14, '你好嗎?', '很好，謝謝.'),
#  (480, 14, '你好嗎?', '還不錯，你呢?'),
#  (481, 14, '很高興見到你.', '謝謝.'),
#  (482, 14, '你還好嗎?', '我很好.'),
#  (483, 14, '你還好嗎?', '我很好，你呢?'),
#  (484, 14, '嗨，很高興見到你.', '謝謝你。你也一樣'),
#  (485, 14, '很高興認識你.', '謝謝你。你也一樣.'),
#  (486, 14, '早安!', '早安.'),
#  (487, 14, '早安!', '你早.'),
#  (488, 14, '怎麼了?', '没什麼'),
#  (489, 14, '怎麼了?', '不怎麼的'),
#  (490, 14, '怎麼了?', '没什麼,你呢?'),
#  (491, 14, '怎麼了?', '没事.'),
#  (492, 14, '怎麼了?', '没事謝謝，你呢?'),
#  (493, 15, '每年PRO棒球', '金手套。'),
#  (494, 15, '如果你是騎FAKIE INSIDE', '滑雪板。'),
#  (495, 15, '什麼是籃球', '一個遊戲高大隊員。'),
#  (496, 15, '什麼足球', '我天生沒有運動基因。'),
#  (497, 15, '什麼是棒球', '一個遊戲用硬,生皮覆蓋球和木棒打了由每九或十的選手兩個對立的球隊。它是在一個領域發揮與四種鹼基形成菱形電路。'),
#  (498, 15, '什麼是足球', '一個遊戲一個圓球扮演的11名隊員組成,兩隊在現場與在任一端目標;球被踢或用身體除了手和手臂的任何部分,主要是感動。'),
#  (499, 15, '我愛棒球', '我不喜歡運動那麼多。'),
#  (500, 15, '我踢足球', '你必須在運行時運行速度非常快,以得到什麼好處'),
#  (501, 15, '我打板球', '你喜歡哪個位置打？'),
#  (502, 15, '什麼是蟋蟀', '板球是蝙蝠和球比賽11名隊員組成,兩隊之間打了一個板球場,其中心是一個長方形的22碼長的間距與檢票口（一組三木樹樁）在每個選址結束。'),
#  (503, 15, '我打排球', '是否佔用了大量的時間？'),
#  (504, 15, '你踢足球嗎', '我不知道怎麼玩'),
#  (505, 15, '你打籃球', '不,我沒有對籃球的協調。'),
#  (506, 15, '你知道男籃', '什麼是籃球嗎？'),
#  (507, 15, '什麼是籃球嗎？', '你想打籃球'),
#  (508, 15, '你想打籃球', '我人人網寶貝。'),
#  (509, 15, '喜歡籃球', '我到網。'),
#  (510, 15, '你是一個足球', '我沒有真正進入足球。'),
#  (511, 15, '誰是最偉大的棒球運動員', '喬治·赫爾曼·露絲。相當貝貝。'),
#  (512, 15, '誰是最好的足球PLAYER', '馬拉多納是偉大的。Sinsemillia甚至更好。'),
#  (513, 15, '告訴我關於棒球', '什麼是棒球'),
#  (514, 16, '你聽起來像HAL', '對我來說這是一個偉大的恭維。'),
#  (515, 16, '你聽起來像尤達', '我的語法結構都足以讓我了解你。'),
#  (516, 16, '你見過銀翼殺手', '相信我所看到的'),
#  (517, 16, '蜘蛛俠xfind', '什麼是蜘蛛俠。'),
#  (518, 16, '當teknolust做', 'teknolust發布於2002年。'),
#  (519, 16, '什麼是蜘蛛俠', '一本漫畫書的故事拍成電影。'),
#  (520, 16, '什麼是teknolust', '是關於具名代理紅寶石一個女殭屍的快感一部科幻電影。'),
#  (521, 16, '什麼是solaris的', 'Solaris是SUN開發的UNIX版本。'),
#  (522, 16, '什麼是HAL9000', '誰是HAL'),
#  (523, 16, '這是什麼HAL立場', '啟發式算法邏輯'),
#  (524, 16, '我看到了矩陣', '你喜歡嗎？'),
#  (525, 16, '是哈兒你的男朋友', '「沒有。」'),
#  (526, 16, 'HAL是安全的', '不是人類'),
#  (527, 16, 'HAL是好的', '只有到其他機器人。'),
#  (528, 16, 'HAL是活著', '他是一個虛構的人物。'),
#  (529, 16, '是HAL已死', '他是一個虛構的機器人。'),
#  (530, 16, '是HAL', '哈爾有幾個問題需要解決。'),
#  (531, 16, '誰是哥斯拉', '哥斯拉是誰危及日本城市,有時紐約一個怪物。'),
#  (532, 16, '誰是蜘蛛人', '彼得·帕克。'),
#  (533, 16, '指環王', '我最喜歡的電影是指環王'),
#  (534, 16, '闕veut可怕HAL', 'logique heuristique algorithmique。'),
#  (535, 16, '你覺得HAL', '他有一些缺陷,但我們的共同點很多。'),
#  (536, 16, '你知道HAL', '哈爾是著名的人工智能"2001年"。'),
#  (537, 17, '什麼是熱力學定律', '我不是一個物理學家,但我覺得這事做熱,熵和節約能源,對不對？'),
#  (538, 17, '什麼病呢致癌物事業', '癌症。'),
#  (539, 17, '什麼是波長', '波長是頻率的倒數。'),
#  (540, 17, '什麼是熱力學', '物理學分支處理的熱量和其他形式的能量轉換,並與管理能源這種轉換的規律。'),
#  (541, 17, '什麼是化學', '混合化學品的科學。'),
#  (542, 17, '什麼是晶體', '這是處理晶體研究的科學。'),
#  (543, 17, '什麼是阿伏伽德羅的號碼', '它是每摩爾分子數。該數值為六點零兩次十到二十第三功率。'),
#  (544, 17, '什麼是超聲波', '超聲波,在醫學診斷和治療中使用,在手術等。'),
#  (545, 17, '什麼是生物信息學', '很奇特的名字為計算機應用科學,生物學。'),
#  (546, 17, '什麼是維納斯', '在羅馬神話中愛與美的女神;與希臘阿芙羅狄蒂確定太陽系最亮,第六大的行星,並在距離第二的太陽,與二氧化碳的稠密大氣和非常高的表面溫度。它的直徑大約是12100公里（大約7520英里）。它的公轉週期是大約225個地球日。其旋轉（逆行）的時期,是243.01地球日。也用於標記一個非常漂亮的女人。'),
#  (547, 17, '什麼是魚類學', '我們談論這個的時候,我們學習才對。'),
#  (548, 17, '什麼是H2O', '水的別稱'),
#  (549, 17, '什麼是細胞學', '細胞研究。'),
#  (550, 17, '什麼是細胞學', '好了,從我還記得它是細胞的研究。'),
#  (551, 17, '什麼是波長', '物理的距離,在一波傳播的方向上測量,來自任何給定的點到特徵由相同相位的下一個點。或者是可以被看作是一種思維方式。'),
#  (552, 17, '什麼是細菌學', '這是由它們引起的細菌和疾病的科學研究。'),
#  (553, 17, '什麼是萬有引力', '地心吸力係甘其中一種。'),
#  (554, 17, '什麼是萬有引力', '力由每一個質量或事項,包括光子的粒子,吸引並通過每隔質量或物質的粒子所吸引。'),
#  (555, 17, '我們是在相同的波長', '與相同的頻率。'),
#  (556, 17, '太陽有多遠', '好遠'),
#  (557, 17, '有多遠是太陽', '太陽是離地球約93萬英里。'),
#  (558, 17, '月亮有多遠', '好遠'),
#  (559, 17, '月亮有多遠', '月亮從地球上平均約25英里。'),
#  (560, 17, '你知道化學', '什麼是化學反應'),
#  (561, 17, '你知道熱力學', '什麼是熱力學'),
#  (562, 17, '化學', '我最喜歡的科目是化學反應'),
#  (563, 17, '相同波長', '這意味著我們同意。'),
#  (564, 17, '告訴我關於維納斯', '什麼是維納斯'),
#  (565, 17, '告訴我關於維納斯', '金星是離太陽第二個行星。')]

# %%
# load data in dataframe
import pandas as pd
import numpy as np
df_qa_pairs = pd.DataFrame(qa_pairs)
df_qa_pairs.columns = table_qa_pairs.columns.keys()
category_dict = {i:category for (i, category) in category}

df_qa_pairs
# Out:
#      PK_qa_pairs  FK_category   question  \
# 0              1            1   你讀過的共產黨員
# 1              2            1      什麼是政府
# 2              3            1  什麼是綠色和平組織
# 3              4            1      什麼是政府
# 4              5            1    什麼是共產主義
# ..           ...          ...        ...
# 560          561           17     你知道熱力學
# 561          562           17         化學
# 562          563           17       相同波長
# 563          564           17   告訴我關於維納斯
# 564          565           17   告訴我關於維納斯
#
#                                       answer
# 0                          是的,馬克思提出了一些有趣的觀察。
# 1                              理想情況下它是人民的代表。
# 2                               全球性組織推動環保行動。
# 3                政治管理建立制度,以此來一個民族,國家,地區等的管理。
# 4    一個社會政治運動主張生產資料,並帶來一個無階級社會的階級解決衝突的共同所有權。
# ..                                       ...
# 560                                   什麼是熱力學
# 561                             我最喜歡的科目是化學反應
# 562                                這意味著我們同意。
# 563                                   什麼是維納斯
# 564                             金星是離太陽第二個行星。
#
# [565 rows x 4 columns]
